# %%
import pandas as pd
import statsapi
import json
from concurrent.futures import ThreadPoolExecutor
import re
from pybaseball import team_batting

# Function to parse raw pitcher stats and return specific fields as a dictionary
def getKStats(raw_data, name):
    lines = [line.strip() for line in raw_data.split('\n') if line.strip()]
    relevant_lines = lines[2:]
    data = {}
    for line in relevant_lines:
        key, value = line.split(':')
        data[key.strip()] = value.strip()
    specific_fields = {
        "Name": name,
        "GP": data.get("gamesPlayed"),
        "AB": data.get("atBats"),
        "AVG": data.get("avg"),
        "S%": data.get("strikePercentage"),
        "P/I": data.get("pitchesPerInning"),
        "K": data.get("strikeOuts"),
        "K/9": data.get("strikeoutsPer9Inn")
    }
    return specific_fields

# Function to fetch pitcher stats and return them as a dictionary
def getPitcherStats(name, team, opponent):
    try:
        player = statsapi.lookup_player(name)
        if not player:
            raise ValueError(f"Player {name} not found")
        id = player[0]['id']
        stats = statsapi.player_stats(id, group="[pitching]", type="season")
        pitcher_stats = getKStats(stats, name)
        pitcher_stats["Opponent"] = opponent
        return pitcher_stats
    except Exception as e:
        return {"Name": name, "Team": team, "Opponent": opponent, "Error": str(e)}

# Fetch schedule for the specified date
sched = statsapi.schedule(start_date='05/25/2024', end_date='05/25/2024')

# Prepare a list to store the tasks
pitcher_tasks = []

for game in sched:
    away_team = game['away_name']
    home_team = game['home_name']
    away_pitcher = game['away_probable_pitcher']
    home_pitcher = game['home_probable_pitcher']
    
    if away_pitcher:
        pitcher_tasks.append((away_pitcher, away_team, home_team))
    if home_pitcher:
        pitcher_tasks.append((home_pitcher, home_team, away_team))

# Fetch pitcher stats using parallel processing
def fetch_stats(pitcher_name, team_name, opponent_name):
    return getPitcherStats(pitcher_name, team_name, opponent_name)

with ThreadPoolExecutor() as executor:
    # Create tasks for fetching pitcher stats
    futures = [executor.submit(fetch_stats, pitcher, team, opponent) for pitcher, team, opponent in pitcher_tasks]

    # Collect results
    results = [future.result() for future in futures]

# %%
df = team_batting(2024)

df['SO/AB'] = (100 * df['SO'] / df['AB']) 
df = df[['Team', 'SO/AB']]
df = df.sort_values(by='SO/AB', ascending=False)

def map_abbreviation_to_full_name(abbreviation):
    team_mapping = {
        "SEA": "Seattle Mariners",
        "OAK": "Oakland Athletics",
        "CIN": "Cincinnati Reds",
        "BOS": "Boston Red Sox",
        "COL": "Colorado Rockies",
        "PIT": "Pittsburgh Pirates",
        "TBR": "Tampa Bay Rays",
        "DET": "Detroit Tigers",
        "MIN": "Minnesota Twins",
        "CHC": "Chicago Cubs",
        "ATL": "Atlanta Braves",
        "MIL": "Milwaukee Brewers",
        "CHW": "Chicago White Sox",
        "LAA": "Los Angeles Angels",
        "STL": "St. Louis Cardinals",
        "WSN": "Washington Nationals",
        "LAD": "Los Angeles Dodgers",
        "PHI": "Philadelphia Phillies",
        "BAL": "Baltimore Orioles",
        "SFG": "San Francisco Giants",
        "MIA": "Miami Marlins",
        "TEX": "Texas Rangers",
        "NYM": "New York Mets",
        "ARI": "Arizona Diamondbacks",
        "CLE": "Cleveland Guardians",
        "TOR": "Toronto Blue Jays",
        "NYY": "New York Yankees",
        "SDP": "San Diego Padres",
        "KCR": "Kansas City Royals",
        "HOU": "Houston Astros"
    }
    
    return team_mapping.get(abbreviation, "Unknown")  # Return the full name or "Unknown" if not found

df['Team'] = df['Team'].apply(map_abbreviation_to_full_name)

# %%
# Convert list of dictionaries to DataFrame
main = pd.DataFrame(results)

pitchers = pd.merge(main, df, left_on='Opponent', right_on='Team', how='left')
pitchers.drop(columns=['Team'], inplace=True)
pitchers['AB/GP'] = (pitchers['AB'].astype(float) / pitchers['GP'].astype(float))
pitchers['K/AB'] = 100 * (pitchers['K'].astype(float) / pitchers['AB'].astype(float))

pitchers = pitchers.sort_values(by='SO/AB', ascending=False)
pitchers = pitchers[['Name', 'GP', 'AB', 'K', 'AVG', 'S%', 'P/I','K/9', 'AB/GP','K/AB', 'SO/AB', 'Opponent']]
pitchers = pitchers.style.background_gradient(cmap='YlGnBu', subset=['SO/AB', "AB/GP", "K/AB"])
pitchers.format({'SO/AB': '{:.2f}', 'AB/GP': '{:.1f}','K/AB': '{:.2f}'})

pitchers
# Out:
# <style type="text/css">
# #T_e20f6_row0_col8, #T_e20f6_row4_col9, #T_e20f6_row7_col10 {
#   background-color: #2195c0;
#   color: #f1f1f1;
# }
# #T_e20f6_row0_col9 {
#   background-color: #87d0ba;
#   color: #000000;
# }
# #T_e20f6_row0_col10, #T_e20f6_row5_col8, #T_e20f6_row24_col9 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_e20f6_row1_col8 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_e20f6_row1_col9 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_e20f6_row1_col10 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# #T_e20f6_row2_col8 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
# }
# #T_e20f6_row2_col9 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_e20f6_row2_col10 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_e20f6_row3_col8 {
#   background-color: #253997;
#   color: #f1f1f1;
# }
# #T_e20f6_row3_col9 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_e20f6_row3_col10 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_e20f6_row4_col8, #T_e20f6_row28_col8 {
#   background-color: #2259a6;
#   color: #f1f1f1;
# }
# #T_e20f6_row4_col10 {
#   background-color: #216bae;
#   color: #f1f1f1;
# }
# #T_e20f6_row5_col9 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_e20f6_row5_col10 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_e20f6_row6_col8 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_e20f6_row6_col9 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_e20f6_row6_col10 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_e20f6_row7_col8 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_e20f6_row7_col9 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_e20f6_row8_col8 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_e20f6_row8_col9 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_e20f6_row8_col10 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_e20f6_row9_col8, #T_e20f6_row22_col8 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_e20f6_row9_col9, #T_e20f6_row12_col8 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_e20f6_row9_col10 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_e20f6_row10_col8 {
#   background-color: #2356a4;
#   color: #f1f1f1;
# }
# #T_e20f6_row10_col9 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_e20f6_row10_col10 {
#   background-color: #2ea3c2;
#   color: #f1f1f1;
# }
# #T_e20f6_row11_col8 {
#   background-color: #162874;
#   color: #f1f1f1;
# }
# #T_e20f6_row11_col9, #T_e20f6_row16_col10 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_e20f6_row11_col10 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_e20f6_row12_col9 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_e20f6_row12_col10 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_e20f6_row13_col8, #T_e20f6_row26_col8 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_e20f6_row13_col9 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_e20f6_row13_col10, #T_e20f6_row14_col10 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
# }
# #T_e20f6_row14_col8, #T_e20f6_row21_col9, #T_e20f6_row29_col10 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e20f6_row14_col9, #T_e20f6_row19_col9, #T_e20f6_row27_col9 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_e20f6_row15_col8 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_e20f6_row15_col9 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
# }
# #T_e20f6_row15_col10, #T_e20f6_row18_col9 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_e20f6_row16_col8, #T_e20f6_row24_col8 {
#   background-color: #2354a3;
#   color: #f1f1f1;
# }
# #T_e20f6_row16_col9 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_e20f6_row17_col8 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_e20f6_row17_col9 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_e20f6_row17_col10 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_e20f6_row18_col8, #T_e20f6_row25_col8 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_e20f6_row18_col10 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_e20f6_row19_col8 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_e20f6_row19_col10 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_e20f6_row20_col8 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_e20f6_row20_col9 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_e20f6_row20_col10 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_e20f6_row21_col8 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_e20f6_row21_col10 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_e20f6_row22_col9 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_e20f6_row22_col10 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_e20f6_row23_col8 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_e20f6_row23_col9 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_e20f6_row23_col10, #T_e20f6_row24_col10, #T_e20f6_row25_col10 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_e20f6_row25_col9 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_e20f6_row26_col9 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_e20f6_row26_col10 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_e20f6_row27_col8 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_e20f6_row27_col10 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_e20f6_row28_col9 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_e20f6_row28_col10 {
#   background-color: #eef8b3;
#   color: #000000;
# }
# #T_e20f6_row29_col8 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_e20f6_row29_col9 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# </style>
# <table id="T_e20f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e20f6_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e20f6_level0_col1" class="col_heading level0 col1" >GP</th>
#       <th id="T_e20f6_level0_col2" class="col_heading level0 col2" >AB</th>
#       <th id="T_e20f6_level0_col3" class="col_heading level0 col3" >K</th>
#       <th id="T_e20f6_level0_col4" class="col_heading level0 col4" >AVG</th>
#       <th id="T_e20f6_level0_col5" class="col_heading level0 col5" >S%</th>
#       <th id="T_e20f6_level0_col6" class="col_heading level0 col6" >P/I</th>
#       <th id="T_e20f6_level0_col7" class="col_heading level0 col7" >K/9</th>
#       <th id="T_e20f6_level0_col8" class="col_heading level0 col8" >AB/GP</th>
#       <th id="T_e20f6_level0_col9" class="col_heading level0 col9" >K/AB</th>
#       <th id="T_e20f6_level0_col10" class="col_heading level0 col10" >SO/AB</th>
#       <th id="T_e20f6_level0_col11" class="col_heading level0 col11" >Opponent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e20f6_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_e20f6_row0_col0" class="data row0 col0" >Trevor Williams</td>
#       <td id="T_e20f6_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_e20f6_row0_col2" class="data row0 col2" >164</td>
#       <td id="T_e20f6_row0_col3" class="data row0 col3" >35</td>
#       <td id="T_e20f6_row0_col4" class="data row0 col4" >.220</td>
#       <td id="T_e20f6_row0_col5" class="data row0 col5" >.620</td>
#       <td id="T_e20f6_row0_col6" class="data row0 col6" >16.11</td>
#       <td id="T_e20f6_row0_col7" class="data row0 col7" >6.85</td>
#       <td id="T_e20f6_row0_col8" class="data row0 col8" >18.2</td>
#       <td id="T_e20f6_row0_col9" class="data row0 col9" >21.34</td>
#       <td id="T_e20f6_row0_col10" class="data row0 col10" >31.27</td>
#       <td id="T_e20f6_row0_col11" class="data row0 col11" >Seattle Mariners</td>
#     </tr>
#     <tr>
#       <th id="T_e20f6_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_e20f6_row1_col0" class="data row1 col0" >Spencer Arrighetti</td>
#       <td id="T_e20f6_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_e20f6_row1_col2" class="data row1 col2" >134</td>
#       <td id="T_e20f6_row1_col3" class="data row1 col3" >36</td>
#       <td id="T_e20f6_row1_col4" class="data row1 col4" >.313</td>
#       <td id="T_e20f6_row1_col5" class="data row1 col5" >.650</td>
#       <td id="T_e20f6_row1_col6" class="data row1 col6" >19.0
