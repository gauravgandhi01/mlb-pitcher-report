# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import statsapi
from concurrent.futures import ThreadPoolExecutor
from pybaseball import team_batting
import sys
import datetime

# %%
def parse_pitcher_stats(raw_data, name):
    lines = [line.strip() for line in raw_data.split('\n') if line.strip()]
    relevant_lines = lines[2:]
    data = {}
    print(relevant_lines)
    for line in relevant_lines:
        key, value = line.split(':')
        data[key.strip()] = value.strip()
    specific_fields = {
        "Name": name,
        "GP": data.get("gamesPlayed"),
        "AB": data.get("atBats"),
        "AVG": data.get("avg"),
        "S%": data.get("strikePercentage"),
        "P/I": data.get("pitchesPerInning"),
        "K": data.get("strikeOuts"),
        "K/9": data.get("strikeoutsPer9Inn")
    }
    return specific_fields

# %%
def fetch_pitcher_stats(name, team, opponent):
    try:
        player = statsapi.lookup_player(name)
        if not player:
            raise ValueError(f"Player {name} not found")
        player_id = player[0]['id']
        stats = statsapi.player_stats(player_id, group="[pitching]", type="season")
        pitcher_stats = parse_pitcher_stats(stats, name)
        pitcher_stats["Opponent"] = opponent
        return pitcher_stats
    except Exception as e:
        return {"Name": name, "Team": team, "Opponent": opponent, "Error": str(e)}

def get_team_full_name(abbreviation):
    team_mapping = {
        "SEA": "Seattle Mariners",
        "OAK": "Oakland Athletics",
        "CIN": "Cincinnati Reds",
        "BOS": "Boston Red Sox",
        "COL": "Colorado Rockies",
        "PIT": "Pittsburgh Pirates",
        "TBR": "Tampa Bay Rays",
        "DET": "Detroit Tigers",
        "MIN": "Minnesota Twins",
        "CHC": "Chicago Cubs",
        "ATL": "Atlanta Braves",
        "MIL": "Milwaukee Brewers",
        "CHW": "Chicago White Sox",
        "LAA": "Los Angeles Angels",
        "STL": "St. Louis Cardinals",
        "WSN": "Washington Nationals",
        "LAD": "Los Angeles Dodgers",
        "PHI": "Philadelphia Phillies",
        "BAL": "Baltimore Orioles",
        "SFG": "San Francisco Giants",
        "MIA": "Miami Marlins",
        "TEX": "Texas Rangers",
        "NYM": "New York Mets",
        "ARI": "Arizona Diamondbacks",
        "CLE": "Cleveland Guardians",
        "TOR": "Toronto Blue Jays",
        "NYY": "New York Yankees",
        "SDP": "San Diego Padres",
        "KCR": "Kansas City Royals",
        "HOU": "Houston Astros"
    }
    return team_mapping.get(abbreviation, "Unknown")

# %%
def get_pitcher_data(pitcher_div):
    player_info = pitcher_div.find('div', class_='player-info')
    if not player_info:
        return 'Unknown',"N/A","N/A"
    
    name_tag = player_info.find('h3').find('a')
    name = name_tag.get_text(strip=True) if name_tag else 'Unknown'
    
    probable_stats = pitcher_div.find('p', class_='probable-stats')
    if probable_stats:
        table = probable_stats.find('table', class_='pitcher-stats')
        if table:
            rows = table.find_all('tr')
            if len(rows) > 1:
                data_row = rows[1].find_all('td')
                if len(data_row) >= 2:
                    pa = data_row[0].get_text(strip=True)
                    k_percentage = data_row[1].get_text(strip=True)
                    return name, pa, k_percentage
    return name, 0, 0

# %%
def getOppData(date):
    date_obj = datetime.datetime.strptime(date, "%m/%d/%Y")
    converted_date = date_obj.strftime("%Y-%m-%d")
    url = f"https://baseballsavant.mlb.com/probable-pitchers?date={converted_date}"
    response = requests.get(url)

    data = []

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        blocks = soup.find_all('div', class_='mod')

        for block in blocks:
            cols = block.find_all('div', class_='col')
            for col in cols:
                name, pa, k_percentage = get_pitcher_data(col)
                data.append({"Pitcher": name, "PA": pa, "K%": k_percentage})
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    df = pd.DataFrame(data)
    return df

# %%
def main(date):
    # Fetch the schedule for the given date
    sched = statsapi.schedule(start_date=date, end_date=date)
    pitcher_tasks = []

    # Collect tasks for fetching pitcher stats
    for game in sched:
        away_team, home_team = game['away_name'], game['home_name']
        if game['away_probable_pitcher']:
            pitcher_tasks.append((game['away_probable_pitcher'], away_team, home_team))
        if game['home_probable_pitcher']:
            pitcher_tasks.append((game['home_probable_pitcher'], home_team, away_team))

    # Fetch pitcher stats using ThreadPoolExecutor
    with ThreadPoolExecutor() as executor:
        results = [future.result() for future in 
                   [executor.submit(fetch_pitcher_stats, pitcher, team, opponent) 
                    for pitcher, team, opponent in pitcher_tasks]]

    # Prepare team batting dataframe
    df = team_batting(2024)
    df['SO/AB'] = (100 * df['SO'] / df['AB'])
    df = df[['Team', 'SO/AB']].sort_values(by='SO/AB', ascending=False)
    df['Team'] = df['Team'].apply(get_team_full_name)

    # Merge pitcher stats with team batting data
    main_df = pd.DataFrame(results)
    merged = pd.merge(main_df, df, left_on='Opponent', right_on='Team', how='left')
    
    # Get opponent data and merge it
    opp_df = getOppData(date)
    pitchers = pd.merge(merged, opp_df, left_on='Name', right_on='Pitcher', how='left')
    pitchers.drop(columns=['Team'], inplace=True)
    
    # Calculate additional metrics
    pitchers['AB/GP'] = pitchers['AB'].astype(float) / pitchers['GP'].astype(float)
    pitchers['K/AB'] = 100 * (pitchers['K'].astype(float) / pitchers['AB'].astype(float))
    pitchers = pitchers.sort_values(by=['SO/AB'], ascending=False)
    
    # Select and style the final columns
    pitchers = pitchers[['Name', 'GP', 'AB', 'K', 'AVG', 'S%', 'P/I', 'K/9', 'AB/GP', 'K/AB', 'PA', 'K%', 'SO/AB', 'Opponent']]
    
    styled_pitchers = pitchers.style.background_gradient(cmap='YlGnBu', subset=['SO/AB', "AB/GP", "K/AB", 'K%', 'PA'])
    styled_pitchers = (styled_pitchers
                       .format({'SO/AB': '{:.2f}', 'AB/GP': '{:.1f}', 'K/AB': '{:.2f}'})
                       .set_properties(**{'text-align': 'center'})
                       .set_table_styles(
                           [{'selector': 'th', 'props': [('font-size', '14px'), ('background-color', '#f4f4f4')]},
                            {'selector': 'td', 'props': [('padding', '6px'), ('border', '1px solid #ddd')]}]))
    return styled_pitchers
# Out:
# ['gamesPlayed: 10', 'gamesStarted: 8', 'groundOuts: 55', 'airOuts: 56', 'runs: 18', 'doubles: 8', 'triples: 1', 'homeRuns: 4', 'strikeOuts: 36', 'baseOnBalls: 11', 'intentionalWalks: 0', 'hits: 46', 'hitByPitch: 1', 'avg: .238', 'atBats: 193', 'obp: .283', 'slg: .352', 'ops: .635', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 6', 'numberOfPitches: 751', 'era: 2.84', 'inningsPitched: 50.2', 'wins: 5', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 1', 'blownSaves: 0', 'earnedRuns: 16', 'whip: 1.13', 'battersFaced: 205', 'outs: 152', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 507', 'strikePercentage: .680', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 68', 'groundOutsToAirouts: 0.98', 'winPercentage: .714', 'pitchesPerInning: 14.82', 'gamesFinished: 0', 'strikeoutWalkRatio: 3.27', 'strikeoutsPer9Inn: 6.39', 'walksPer9Inn: 1.95', 'hitsPer9Inn: 8.17', 'runsScoredPer9: 3.20', 'homeRunsPer9: 0.71', 'inheritedRunners: 2', 'inheritedRunnersScored: 1', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 52', 'airOuts: 73', 'runs: 25', 'doubles: 13', 'triples: 1', 'homeRuns: 7', 'strikeOuts: 73', 'baseOnBalls: 9', 'intentionalWalks: 0', 'hits: 54', 'hitByPitch: 1', 'avg: .214', 'atBats: 252', 'obp: .244', 'slg: .357', 'ops: .601', 'caughtStealing: 0', 'stolenBases: 7', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 1024', 'era: 2.96', 'inningsPitched: 67.0', 'wins: 4', 'losses: 3', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 22', 'whip: 0.94', 'battersFaced: 262', 'outs: 201', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 702', 'strikePercentage: .690', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 2', 'pickoffs: 0', 'totalBases: 90', 'groundOutsToAirouts: 0.71', 'winPercentage: .571', 'pitchesPerInning: 15.28', 'gamesFinished: 0', 'strikeoutWalkRatio: 8.11', 'strikeoutsPer9Inn: 9.81', 'walksPer9Inn: 1.21', 'hitsPer9Inn: 7.25', 'runsScoredPer9: 3.36', 'homeRunsPer9: 0.94', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 4', 'gamesStarted: 4', 'groundOuts: 12', 'airOuts: 24', 'runs: 20', 'doubles: 1', 'triples: 1', 'homeRuns: 4', 'strikeOuts: 13', 'baseOnBalls: 17', 'intentionalWalks: 0', 'hits: 19', 'hitByPitch: 0', 'avg: .279', 'atBats: 68', 'obp: .424', 'slg: .500', 'ops: .924', 'caughtStealing: 0', 'stolenBases: 6', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 0', 'numberOfPitches: 328', 'era: 9.92', 'inningsPitched: 16.1', 'wins: 0', 'losses: 4', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 18', 'whip: 2.20', 'battersFaced: 85', 'outs: 49', 'gamesPitched: 4', 'completeGames: 0', 'shutouts: 0', 'strikes: 185', 'strikePercentage: .560', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 34', 'groundOutsToAirouts: 0.50', 'winPercentage: .000', 'pitchesPerInning: 20.08', 'gamesFinished: 0', 'strikeoutWalkRatio: 0.76', 'strikeoutsPer9Inn: 7.16', 'walksPer9Inn: 9.37', 'hitsPer9Inn: 10.47', 'runsScoredPer9: 11.02', 'homeRunsPer9: 2.20', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 56', 'airOuts: 60', 'runs: 30', 'doubles: 6', 'triples: 0', 'homeRuns: 7', 'strikeOuts: 56', 'baseOnBalls: 25', 'intentionalWalks: 0', 'hits: 61', 'hitByPitch: 3', 'avg: .264', 'atBats: 231', 'obp: .342', 'slg: .381', 'ops: .723', 'caughtStealing: 2', 'stolenBases: 5', 'stolenBasePercentage: .714', 'groundIntoDoublePlay: 8', 'numberOfPitches: 1053', 'era: 4.03', 'inningsPitched: 60.1', 'wins: 5', 'losses: 6', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 27', 'whip: 1.43', 'battersFaced: 261', 'outs: 181', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 672', 'strikePercentage: .640', 'hitBatsmen: 3', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 88', 'groundOutsToAirouts: 0.93', 'winPercentage: .455', 'pitchesPerInning: 17.45', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.24', 'strikeoutsPer9Inn: 8.35', 'walksPer9Inn: 3.73', 'hitsPer9Inn: 9.10', 'runsScoredPer9: 4.48', 'homeRunsPer9: 1.04', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 1']
# ['gamesPlayed: 3', 'gamesStarted: 3', 'groundOuts: 11', 'airOuts: 19', 'runs: 9', 'doubles: 4', 'triples: 0', 'homeRuns: 2', 'strikeOuts: 8', 'baseOnBalls: 3', 'intentionalWalks: 0', 'hits: 15', 'hitByPitch: 0', 'avg: .283', 'atBats: 53', 'obp: .321', 'slg: .472', 'ops: .793', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 1', 'numberOfPitches: 213', 'era: 5.68', 'inningsPitched: 12.2', 'wins: 0', 'losses: 1', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 8', 'whip: 1.42', 'battersFaced: 56', 'outs: 38', 'gamesPitched: 3', 'completeGames: 0', 'shutouts: 0', 'strikes: 143', 'strikePercentage: .670', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 25', 'groundOutsToAirouts: 0.58', 'winPercentage: .000', 'pitchesPerInning: 16.82', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.67', 'strikeoutsPer9Inn: 5.68', 'walksPer9Inn: 2.13', 'hitsPer9Inn: 10.66', 'runsScoredPer9: 6.39', 'homeRunsPer9: 1.42', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 9', 'gamesStarted: 8', 'groundOuts: 39', 'airOuts: 39', 'runs: 23', 'doubles: 8', 'triples: 1', 'homeRuns: 5', 'strikeOuts: 36', 'baseOnBalls: 9', 'intentionalWalks: 0', 'hits: 37', 'hitByPitch: 2', 'avg: .248', 'atBats: 149', 'obp: .296', 'slg: .416', 'ops: .712', 'caughtStealing: 0', 'stolenBases: 0', 'stolenBasePercentage: .---', 'groundIntoDoublePlay: 6', 'numberOfPitches: 703', 'era: 3.96', 'inningsPitched: 38.2', 'wins: 2', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 17', 'whip: 1.19', 'battersFaced: 162', 'outs: 116', 'gamesPitched: 9', 'completeGames: 0', 'shutouts: 0', 'strikes: 449', 'strikePercentage: .640', 'hitBatsmen: 2', 'balks: 0', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 62', 'groundOutsToAirouts: 1.00', 'winPercentage: .500', 'pitchesPerInning: 18.18', 'gamesFinished: 0', 'strikeoutWalkRatio: 4.00', 'strikeoutsPer9Inn: 8.38', 'walksPer9Inn: 2.09', 'hitsPer9Inn: 8.61', 'runsScoredPer9: 5.35', 'homeRunsPer9: 1.16', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 10', 'gamesStarted: 1', 'groundOuts: 24', 'airOuts: 15', 'runs: 18', 'doubles: 5', 'triples: 0', 'homeRuns: 2', 'strikeOuts: 9', 'baseOnBalls: 10', 'intentionalWalks: 0', 'hits: 25', 'hitByPitch: 1', 'avg: .347', 'atBats: 72', 'obp: .429', 'slg: .500', 'ops: .929', 'caughtStealing: 2', 'stolenBases: 0', 'stolenBasePercentage: .000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 340', 'era: 8.35', 'inningsPitched: 18.1', 'wins: 0', 'losses: 0', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 17', 'whip: 1.91', 'battersFaced: 84', 'outs: 55', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 207', 'strikePercentage: .610', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 2', 'pickoffs: 0', 'totalBases: 36', 'groundOutsToAirouts: 1.60', 'winPercentage: .---', 'pitchesPerInning: 18.55', 'gamesFinished: 7', 'strikeoutWalkRatio: 0.90', 'strikeoutsPer9Inn: 4.42', 'walksPer9Inn: 4.91', 'hitsPer9Inn: 12.27', 'runsScoredPer9: 8.84', 'homeRunsPer9: 0.98', 'inheritedRunners: 4', 'inheritedRunnersScored: 2', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 9', 'gamesStarted: 9', 'groundOuts: 45', 'airOuts: 60', 'runs: 19', 'doubles: 9', 'triples: 1', 'homeRuns: 5', 'strikeOuts: 43', 'baseOnBalls: 14', 'intentionalWalks: 0', 'hits: 39', 'hitByPitch: 1', 'avg: .210', 'atBats: 186', 'obp: .267', 'slg: .349', 'ops: .616', 'caughtStealing: 1', 'stolenBases: 3', 'stolenBasePercentage: .750', 'groundIntoDoublePlay: 1', 'numberOfPitches: 781', 'era: 3.24', 'inningsPitched: 50.0', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 18', 'whip: 1.06', 'battersFaced: 202', 'outs: 150', 'gamesPitched: 9', 'completeGames: 0', 'shutouts: 0', 'strikes: 511', 'strikePercentage: .650', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 65', 'groundOutsToAirouts: 0.75', 'winPercentage: .667', 'pitchesPerInning: 15.62', 'gamesFinished: 0', 'strikeoutWalkRatio: 3.07', 'strikeoutsPer9Inn: 7.74', 'walksPer9Inn: 2.52', 'hitsPer9Inn: 7.02', 'runsScoredPer9: 3.42', 'homeRunsPer9: 0.90', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 52', 'airOuts: 64', 'runs: 30', 'doubles: 13', 'triples: 0', 'homeRuns: 7', 'strikeOuts: 53', 'baseOnBalls: 23', 'intentionalWalks: 0', 'hits: 54', 'hitByPitch: 3', 'avg: .244', 'atBats: 221', 'obp: .321', 'slg: .398', 'ops: .719', 'caughtStealing: 3', 'stolenBases: 7', 'stolenBasePercentage: .700', 'groundIntoDoublePlay: 4', 'numberOfPitches: 988', 'era: 3.45', 'inningsPitched: 57.1', 'wins: 2', 'losses: 3', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 22', 'whip: 1.34', 'battersFaced: 249', 'outs: 172', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 603', 'strikePercentage: .610', 'hitBatsmen: 3', 'balks: 0', 'wildPitches: 2', 'pickoffs: 0', 'totalBases: 88', 'groundOutsToAirouts: 0.81', 'winPercentage: .400', 'pitchesPerInning: 17.23', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.30', 'strikeoutsPer9Inn: 8.32', 'walksPer9Inn: 3.61', 'hitsPer9Inn: 8.48', 'runsScoredPer9: 4.71', 'homeRunsPer9: 1.10', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 8', 'gamesStarted: 8', 'groundOuts: 44', 'airOuts: 46', 'runs: 17', 'doubles: 6', 'triples: 0', 'homeRuns: 5', 'strikeOuts: 38', 'baseOnBalls: 8', 'intentionalWalks: 0', 'hits: 41', 'hitByPitch: 0', 'avg: .246', 'atBats: 167', 'obp: .277', 'slg: .371', 'ops: .648', 'caughtStealing: 0', 'stolenBases: 2', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 672', 'era: 3.45', 'inningsPitched: 44.1', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 17', 'whip: 1.11', 'battersFaced: 177', 'outs: 133', 'gamesPitched: 8', 'completeGames: 0', 'shutouts: 0', 'strikes: 461', 'strikePercentage: .690', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 4', 'pickoffs: 0', 'totalBases: 62', 'groundOutsToAirouts: 0.96', 'winPercentage: .667', 'pitchesPerInning: 15.16', 'gamesFinished: 0', 'strikeoutWalkRatio: 4.75', 'strikeoutsPer9Inn: 7.71', 'walksPer9Inn: 1.62', 'hitsPer9Inn: 8.32', 'runsScoredPer9: 3.45', 'homeRunsPer9: 1.02', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 7', 'gamesStarted: 7', 'groundOuts: 34', 'airOuts: 39', 'runs: 14', 'doubles: 6', 'triples: 0', 'homeRuns: 4', 'strikeOuts: 46', 'baseOnBalls: 9', 'intentionalWalks: 0', 'hits: 29', 'hitByPitch: 4', 'avg: .196', 'atBats: 148', 'obp: .261', 'slg: .318', 'ops: .579', 'caughtStealing: 2', 'stolenBases: 7', 'stolenBasePercentage: .778', 'groundIntoDoublePlay: 0', 'numberOfPitches: 632', 'era: 3.12', 'inningsPitched: 40.1', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 14', 'whip: 0.94', 'battersFaced: 161', 'outs: 121', 'gamesPitched: 7', 'completeGames: 0', 'shutouts: 0', 'strikes: 414', 'strikePercentage: .660', 'hitBatsmen: 4', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 47', 'groundOutsToAirouts: 0.87', 'winPercentage: .667', 'pitchesPerInning: 15.67', 'gamesFinished: 0', 'strikeoutWalkRatio: 5.11', 'strikeoutsPer9Inn: 10.26', 'walksPer9Inn: 2.01', 'hitsPer9Inn: 6.47', 'runsScoredPer9: 3.12', 'homeRunsPer9: 0.89', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 6', 'gamesStarted: 6', 'groundOuts: 32', 'airOuts: 34', 'runs: 17', 'doubles: 7', 'triples: 0', 'homeRuns: 6', 'strikeOuts: 31', 'baseOnBalls: 7', 'intentionalWalks: 0', 'hits: 27', 'hitByPitch: 2', 'avg: .223', 'atBats: 121', 'obp: .275', 'slg: .430', 'ops: .705', 'caughtStealing: 1', 'stolenBases: 0', 'stolenBasePercentage: .000', 'groundIntoDoublePlay: 0', 'numberOfPitches: 483', 'era: 4.45', 'inningsPitched: 32.1', 'wins: 0', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 16', 'whip: 1.05', 'battersFaced: 133', 'outs: 97', 'gamesPitched: 6', 'completeGames: 0', 'shutouts: 0', 'strikes: 330', 'strikePercentage: .680', 'hitBatsmen: 2', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 52', 'groundOutsToAirouts: 0.94', 'winPercentage: .000', 'pitchesPerInning: 14.94', 'gamesFinished: 0', 'strikeoutWalkRatio: 4.43', 'strikeoutsPer9Inn: 8.63', 'walksPer9Inn: 1.95', 'hitsPer9Inn: 7.52', 'runsScoredPer9: 4.73', 'homeRunsPer9: 1.67', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 2', 'sacFlies: 1']
# ['gamesPlayed: 10', 'gamesStarted: 10', 'groundOuts: 53', 'airOuts: 46', 'runs: 29', 'doubles: 14', 'triples: 0', 'homeRuns: 6', 'strikeOuts: 59', 'baseOnBalls: 23', 'intentionalWalks: 0', 'hits: 52', 'hitByPitch: 5', 'avg: .249', 'atBats: 209', 'obp: .336', 'slg: .402', 'ops: .738', 'caughtStealing: 4', 'stolenBases: 5', 'stolenBasePercentage: .556', 'groundIntoDoublePlay: 5', 'numberOfPitches: 927', 'era: 4.29', 'inningsPitched: 56.2', 'wins: 3', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 27', 'whip: 1.32', 'battersFaced: 238', 'outs: 170', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 600', 'strikePercentage: .650', 'hitBatsmen: 5', 'balks: 0', 'wildPitches: 0', 'pickoffs: 2', 'totalBases: 84', 'groundOutsToAirouts: 1.15', 'winPercentage: .600', 'pitchesPerInning: 16.36', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.57', 'strikeoutsPer9Inn: 9.37', 'walksPer9Inn: 3.65', 'hitsPer9Inn: 8.26', 'runsScoredPer9: 4.61', 'homeRunsPer9: 0.95', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 5', 'gamesStarted: 5', 'groundOuts: 19', 'airOuts: 15', 'runs: 23', 'doubles: 6', 'triples: 1', 'homeRuns: 3', 'strikeOuts: 24', 'baseOnBalls: 11', 'intentionalWalks: 0', 'hits: 27', 'hitByPitch: 1', 'avg: .318', 'atBats: 85', 'obp: .402', 'slg: .518', 'ops: .920', 'caughtStealing: 0', 'stolenBases: 8', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 0', 'numberOfPitches: 412', 'era: 10.42', 'inningsPitched: 19.0', 'wins: 0', 'losses: 3', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 22', 'whip: 2.00', 'battersFaced: 97', 'outs: 57', 'gamesPitched: 5', 'completeGames: 0', 'shutouts: 0', 'strikes: 235', 'strikePercentage: .570', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 3', 'pickoffs: 0', 'totalBases: 44', 'groundOutsToAirouts: 1.27', 'winPercentage: .000', 'pitchesPerInning: 21.68', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.18', 'strikeoutsPer9Inn: 11.37', 'walksPer9Inn: 5.21', 'hitsPer9Inn: 12.79', 'runsScoredPer9: 10.89', 'homeRunsPer9: 1.42', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 4', 'gamesStarted: 4', 'groundOuts: 27', 'airOuts: 27', 'runs: 6', 'doubles: 1', 'triples: 0', 'homeRuns: 0', 'strikeOuts: 13', 'baseOnBalls: 1', 'intentionalWalks: 0', 'hits: 21', 'hitByPitch: 3', 'avg: .250', 'atBats: 84', 'obp: .275', 'slg: .262', 'ops: .537', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 322', 'era: 1.96', 'inningsPitched: 23.0', 'wins: 2', 'losses: 0', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 5', 'whip: 0.96', 'battersFaced: 92', 'outs: 69', 'gamesPitched: 4', 'completeGames: 0', 'shutouts: 0', 'strikes: 229', 'strikePercentage: .710', 'hitBatsmen: 3', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 22', 'groundOutsToAirouts: 1.00', 'winPercentage: 1.000', 'pitchesPerInning: 14.00', 'gamesFinished: 0', 'strikeoutWalkRatio: 13.00', 'strikeoutsPer9Inn: 5.09', 'walksPer9Inn: 0.39', 'hitsPer9Inn: 8.22', 'runsScoredPer9: 2.35', 'homeRunsPer9: 0.00', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 3']
# ['gamesPlayed: 6', 'gamesStarted: 6', 'groundOuts: 21', 'airOuts: 44', 'runs: 21', 'doubles: 7', 'triples: 0', 'homeRuns: 6', 'strikeOuts: 25', 'baseOnBalls: 12', 'intentionalWalks: 0', 'hits: 40', 'hitByPitch: 2', 'avg: .310', 'atBats: 129', 'obp: .375', 'slg: .504', 'ops: .879', 'caughtStealing: 2', 'stolenBases: 1', 'stolenBasePercentage: .333', 'groundIntoDoublePlay: 4', 'numberOfPitches: 509', 'era: 5.51', 'inningsPitched: 32.2', 'wins: 3', 'losses: 0', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 20', 'whip: 1.59', 'battersFaced: 144', 'outs: 98', 'gamesPitched: 6', 'completeGames: 0', 'shutouts: 0', 'strikes: 327', 'strikePercentage: .640', 'hitBatsmen: 2', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 65', 'groundOutsToAirouts: 0.48', 'winPercentage: 1.000', 'pitchesPerInning: 15.58', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.08', 'strikeoutsPer9Inn: 6.89', 'walksPer9Inn: 3.31', 'hitsPer9Inn: 11.02', 'runsScoredPer9: 5.79', 'homeRunsPer9: 1.65', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 60', 'airOuts: 43', 'runs: 36', 'doubles: 18', 'triples: 2', 'homeRuns: 6', 'strikeOuts: 42', 'baseOnBalls: 24', 'intentionalWalks: 2', 'hits: 65', 'hitByPitch: 1', 'avg: .313', 'atBats: 208', 'obp: .383', 'slg: .505', 'ops: .888', 'caughtStealing: 1', 'stolenBases: 6', 'stolenBasePercentage: .857', 'groundIntoDoublePlay: 3', 'numberOfPitches: 913', 'era: 5.92', 'inningsPitched: 48.2', 'wins: 1', 'losses: 6', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 32', 'whip: 1.83', 'battersFaced: 235', 'outs: 146', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 572', 'strikePercentage: .630', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 105', 'groundOutsToAirouts: 1.40', 'winPercentage: .143', 'pitchesPerInning: 18.76', 'gamesFinished: 0', 'strikeoutWalkRatio: 1.75', 'strikeoutsPer9Inn: 7.77', 'walksPer9Inn: 4.44', 'hitsPer9Inn: 12.02', 'runsScoredPer9: 6.66', 'homeRunsPer9: 1.11', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 12', 'gamesStarted: 11', 'groundOuts: 60', 'airOuts: 61', 'runs: 35', 'doubles: 10', 'triples: 0', 'homeRuns: 13', 'strikeOuts: 73', 'baseOnBalls: 29', 'intentionalWalks: 1', 'hits: 54', 'hitByPitch: 0', 'avg: .219', 'atBats: 247', 'obp: .301', 'slg: .417', 'ops: .718', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 1', 'numberOfPitches: 1088', 'era: 4.18', 'inningsPitched: 64.2', 'wins: 4', 'losses: 4', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 30', 'whip: 1.28', 'battersFaced: 277', 'outs: 194', 'gamesPitched: 12', 'completeGames: 0', 'shutouts: 0', 'strikes: 698', 'strikePercentage: .640', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 103', 'groundOutsToAirouts: 0.98', 'winPercentage: .500', 'pitchesPerInning: 16.82', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.52', 'strikeoutsPer9Inn: 10.16', 'walksPer9Inn: 4.04', 'hitsPer9Inn: 7.52', 'runsScoredPer9: 4.87', 'homeRunsPer9: 1.81', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 0']
# ['gamesPlayed: 7', 'gamesStarted: 7', 'groundOuts: 64', 'airOuts: 15', 'runs: 20', 'doubles: 7', 'triples: 0', 'homeRuns: 5', 'strikeOuts: 34', 'baseOnBalls: 12', 'intentionalWalks: 0', 'hits: 43', 'hitByPitch: 3', 'avg: .279', 'atBats: 154', 'obp: .339', 'slg: .422', 'ops: .761', 'caughtStealing: 1', 'stolenBases: 2', 'stolenBasePercentage: .667', 'groundIntoDoublePlay: 11', 'numberOfPitches: 619', 'era: 4.32', 'inningsPitched: 41.2', 'wins: 3', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 20', 'whip: 1.32', 'battersFaced: 171', 'outs: 125', 'gamesPitched: 7', 'completeGames: 0', 'shutouts: 0', 'strikes: 388', 'strikePercentage: .630', 'hitBatsmen: 3', 'balks: 1', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 65', 'groundOutsToAirouts: 4.27', 'winPercentage: .600', 'pitchesPerInning: 14.86', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.83', 'strikeoutsPer9Inn: 7.34', 'walksPer9Inn: 2.59', 'hitsPer9Inn: 9.29', 'runsScoredPer9: 4.32', 'homeRunsPer9: 1.08', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 10', 'gamesStarted: 10', 'groundOuts: 47', 'airOuts: 70', 'runs: 25', 'doubles: 6', 'triples: 0', 'homeRuns: 11', 'strikeOuts: 56', 'baseOnBalls: 16', 'intentionalWalks: 0', 'hits: 41', 'hitByPitch: 0', 'avg: .192', 'atBats: 213', 'obp: .248', 'slg: .376', 'ops: .624', 'caughtStealing: 0', 'stolenBases: 3', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 2', 'numberOfPitches: 882', 'era: 3.53', 'inningsPitched: 58.2', 'wins: 3', 'losses: 5', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 23', 'whip: 0.97', 'battersFaced: 230', 'outs: 176', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 575', 'strikePercentage: .650', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 80', 'groundOutsToAirouts: 0.67', 'winPercentage: .375', 'pitchesPerInning: 15.03', 'gamesFinished: 0', 'strikeoutWalkRatio: 3.50', 'strikeoutsPer9Inn: 8.59', 'walksPer9Inn: 2.45', 'hitsPer9Inn: 6.29', 'runsScoredPer9: 3.84', 'homeRunsPer9: 1.69', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 9', 'gamesStarted: 9', 'groundOuts: 57', 'airOuts: 53', 'runs: 20', 'doubles: 9', 'triples: 0', 'homeRuns: 4', 'strikeOuts: 34', 'baseOnBalls: 17', 'intentionalWalks: 0', 'hits: 48', 'hitByPitch: 0', 'avg: .253', 'atBats: 190', 'obp: .313', 'slg: .363', 'ops: .676', 'caughtStealing: 0', 'stolenBases: 3', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 5', 'numberOfPitches: 774', 'era: 3.60', 'inningsPitched: 50.0', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 20', 'whip: 1.30', 'battersFaced: 209', 'outs: 150', 'gamesPitched: 9', 'completeGames: 0', 'shutouts: 0', 'strikes: 498', 'strikePercentage: .640', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 4', 'pickoffs: 1', 'totalBases: 69', 'groundOutsToAirouts: 1.08', 'winPercentage: .667', 'pitchesPerInning: 15.48', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.00', 'strikeoutsPer9Inn: 6.12', 'walksPer9Inn: 3.06', 'hitsPer9Inn: 8.64', 'runsScoredPer9: 3.60', 'homeRunsPer9: 0.72', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 1']
# ['gamesPlayed: 2', 'gamesStarted: 2', 'groundOuts: 4', 'airOuts: 10', 'runs: 5', 'doubles: 2', 'triples: 0', 'homeRuns: 0', 'strikeOuts: 11', 'baseOnBalls: 5', 'intentionalWalks: 0', 'hits: 7', 'hitByPitch: 1', 'avg: .219', 'atBats: 32', 'obp: .342', 'slg: .281', 'ops: .623', 'caughtStealing: 0', 'stolenBases: 4', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 1', 'numberOfPitches: 164', 'era: 3.00', 'inningsPitched: 9.0', 'wins: 0', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 3', 'whip: 1.33', 'battersFaced: 39', 'outs: 27', 'gamesPitched: 2', 'completeGames: 0', 'shutouts: 0', 'strikes: 97', 'strikePercentage: .590', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 9', 'groundOutsToAirouts: 0.40', 'winPercentage: .000', 'pitchesPerInning: 18.22', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.20', 'strikeoutsPer9Inn: 11.00', 'walksPer9Inn: 5.00', 'hitsPer9Inn: 7.00', 'runsScoredPer9: 5.00', 'homeRunsPer9: 0.00', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 1', 'sacBunts: 0', 'sacFlies: 0']
# <style type="text/css">
# #T_38da6 th {
#   font-size: 14px;
#   background-color: #f4f4f4;
# }
# #T_38da6 td {
#   padding: 6px;
#   border: 1px solid #ddd;
# }
# #T_38da6_row0_col0, #T_38da6_row0_col1, #T_38da6_row0_col2, #T_38da6_row0_col3, #T_38da6_row0_col4, #T_38da6_row0_col5, #T_38da6_row0_col6, #T_38da6_row0_col7, #T_38da6_row0_col13, #T_38da6_row1_col0, #T_38da6_row1_col1, #T_38da6_row1_col2, #T_38da6_row1_col3, #T_38da6_row1_col4, #T_38da6_row1_col5, #T_38da6_row1_col6, #T_38da6_row1_col7, #T_38da6_row1_col13, #T_38da6_row2_col0, #T_38da6_row2_col1, #T_38da6_row2_col2, #T_38da6_row2_col3, #T_38da6_row2_col4, #T_38da6_row2_col5, #T_38da6_row2_col6, #T_38da6_row2_col7, #T_38da6_row2_col13, #T_38da6_row3_col0, #T_38da6_row3_col1, #T_38da6_row3_col2, #T_38da6_row3_col3, #T_38da6_row3_col4, #T_38da6_row3_col5, #T_38da6_row3_col6, #T_38da6_row3_col7, #T_38da6_row3_col13, #T_38da6_row4_col0, #T_38da6_row4_col1, #T_38da6_row4_col2, #T_38da6_row4_col3, #T_38da6_row4_col4, #T_38da6_row4_col5, #T_38da6_row4_col6, #T_38da6_row4_col7, #T_38da6_row4_col13, #T_38da6_row5_col0, #T_38da6_row5_col1, #T_38da6_row5_col2, #T_38da6_row5_col3, #T_38da6_row5_col4, #T_38da6_row5_col5, #T_38da6_row5_col6, #T_38da6_row5_col7, #T_38da6_row5_col13, #T_38da6_row6_col0, #T_38da6_row6_col1, #T_38da6_row6_col2, #T_38da6_row6_col3, #T_38da6_row6_col4, #T_38da6_row6_col5, #T_38da6_row6_col6, #T_38da6_row6_col7, #T_38da6_row6_col13, #T_38da6_row7_col0, #T_38da6_row7_col1, #T_38da6_row7_col2, #T_38da6_row7_col3, #T_38da6_row7_col4, #T_38da6_row7_col5, #T_38da6_row7_col6, #T_38da6_row7_col7, #T_38da6_row7_col13, #T_38da6_row8_col0, #T_38da6_row8_col1, #T_38da6_row8_col2, #T_38da6_row8_col3, #T_38da6_row8_col4, #T_38da6_row8_col5, #T_38da6_row8_col6, #T_38da6_row8_col7, #T_38da6_row8_col13, #T_38da6_row9_col0, #T_38da6_row9_col1, #T_38da6_row9_col2, #T_38da6_row9_col3, #T_38da6_row9_col4, #T_38da6_row9_col5, #T_38da6_row9_col6, #T_38da6_row9_col7, #T_38da6_row9_col13, #T_38da6_row10_col0, #T_38da6_row10_col1, #T_38da6_row10_col2, #T_38da6_row10_col3, #T_38da6_row10_col4, #T_38da6_row10_col5, #T_38da6_row10_col6, #T_38da6_row10_col7, #T_38da6_row10_col13, #T_38da6_row11_col0, #T_38da6_row11_col1, #T_38da6_row11_col2, #T_38da6_row11_col3, #T_38da6_row11_col4, #T_38da6_row11_col5, #T_38da6_row11_col6, #T_38da6_row11_col7, #T_38da6_row11_col13, #T_38da6_row12_col0, #T_38da6_row12_col1, #T_38da6_row12_col2, #T_38da6_row12_col3, #T_38da6_row12_col4, #T_38da6_row12_col5, #T_38da6_row12_col6, #T_38da6_row12_col7, #T_38da6_row12_col13, #T_38da6_row13_col0, #T_38da6_row13_col1, #T_38da6_row13_col2, #T_38da6_row13_col3, #T_38da6_row13_col4, #T_38da6_row13_col5, #T_38da6_row13_col6, #T_38da6_row13_col7, #T_38da6_row13_col13, #T_38da6_row14_col0, #T_38da6_row14_col1, #T_38da6_row14_col2, #T_38da6_row14_col3, #T_38da6_row14_col4, #T_38da6_row14_col5, #T_38da6_row14_col6, #T_38da6_row14_col7, #T_38da6_row14_col13, #T_38da6_row15_col0, #T_38da6_row15_col1, #T_38da6_row15_col2, #T_38da6_row15_col3, #T_38da6_row15_col4, #T_38da6_row15_col5, #T_38da6_row15_col6, #T_38da6_row15_col7, #T_38da6_row15_col13, #T_38da6_row16_col0, #T_38da6_row16_col1, #T_38da6_row16_col2, #T_38da6_row16_col3, #T_38da6_row16_col4, #T_38da6_row16_col5, #T_38da6_row16_col6, #T_38da6_row16_col7, #T_38da6_row16_col13, #T_38da6_row17_col0, #T_38da6_row17_col1, #T_38da6_row17_col2, #T_38da6_row17_col3, #T_38da6_row17_col4, #T_38da6_row17_col5, #T_38da6_row17_col6, #T_38da6_row17_col7, #T_38da6_row17_col13, #T_38da6_row18_col0, #T_38da6_row18_col1, #T_38da6_row18_col2, #T_38da6_row18_col3, #T_38da6_row18_col4, #T_38da6_row18_col5, #T_38da6_row18_col6, #T_38da6_row18_col7, #T_38da6_row18_col13, #T_38da6_row19_col0, #T_38da6_row19_col1, #T_38da6_row19_col2, #T_38da6_row19_col3, #T_38da6_row19_col4, #T_38da6_row19_col5, #T_38da6_row19_col6, #T_38da6_row19_col7, #T_38da6_row19_col13, #T_38da6_row20_col0, #T_38da6_row20_col1, #T_38da6_row20_col2, #T_38da6_row20_col3, #T_38da6_row20_col4, #T_38da6_row20_col5, #T_38da6_row20_col6, #T_38da6_row20_col7, #T_38da6_row20_col13, #T_38da6_row21_col0, #T_38da6_row21_col1, #T_38da6_row21_col2, #T_38da6_row21_col3, #T_38da6_row21_c ...
#   text-align: center;
# }
# #T_38da6_row0_col8 {
#   background-color: #152772;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row0_col9 {
#   background-color: #5fc1c0;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row0_col10, #T_38da6_row0_col12, #T_38da6_row10_col9, #T_38da6_row11_col11, #T_38da6_row20_col8 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row0_col11, #T_38da6_row8_col12 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row1_col8 {
#   background-color: #24459c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row1_col9 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row1_col10, #T_38da6_row14_col12 {
#   background-color: #89d1ba;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row1_col11, #T_38da6_row2_col12 {
#   background-color: #2258a5;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row1_col12 {
#   background-color: #24489d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row2_col8 {
#   background-color: #2356a4;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row2_col9 {
#   background-color: #b4e2b6;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row2_col10 {
#   background-color: #a7dcb7;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row2_col11 {
#   background-color: #59bfc0;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row3_col8 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row3_col9 {
#   background-color: #eef8b3;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row3_col10 {
#   background-color: #f8fcc9;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row3_col11 {
#   background-color: #aedfb6;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row3_col12 {
#   background-color: #216bae;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row4_col8, #T_38da6_row7_col8 {
#   background-color: #243392;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row4_col9 {
#   background-color: #eaf7b1;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row4_col10, #T_38da6_row4_col11, #T_38da6_row9_col10, #T_38da6_row9_col11, #T_38da6_row13_col10, #T_38da6_row13_col11, #T_38da6_row16_col8, #T_38da6_row16_col9, #T_38da6_row16_col10, #T_38da6_row16_col11, #T_38da6_row18_col11, #T_38da6_row21_col12 {
#   background-color: #ffffd9;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row4_col12, #T_38da6_row12_col8, #T_38da6_row12_col10, #T_38da6_row18_col8 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row5_col8 {
#   background-color: #24449c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row5_col9 {
#   background-color: #2498c1;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row5_col10 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row5_col11 {
#   background-color: #2165ab;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row5_col12 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row6_col8 {
#   background-color: #253997;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row6_col9 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row6_col10, #T_38da6_row8_col10, #T_38da6_row15_col10, #T_38da6_row17_col10 {
#   background-color: #f0f9b8;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row6_col11, #T_38da6_row17_col11 {
#   background-color: #289cc1;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row6_col12 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row7_col9 {
#   background-color: #36abc3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_38da6_row7_col10, #T_38da6_row11_col10 {
#   background-color: #4ebbc2;
#   color: #000000;
#   text-align: center;
# }
# #T_38da6_row7

# %%
main("5/27/2024")
# Out:
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 52', 'airOuts: 73', 'runs: 25', 'doubles: 13', 'triples: 1', 'homeRuns: 7', 'strikeOuts: 73', 'baseOnBalls: 9', 'intentionalWalks: 0', 'hits: 54', 'hitByPitch: 1', 'avg: .214', 'atBats: 252', 'obp: .244', 'slg: .357', 'ops: .601', 'caughtStealing: 0', 'stolenBases: 7', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 1024', 'era: 2.96', 'inningsPitched: 67.0', 'wins: 4', 'losses: 3', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 22', 'whip: 0.94', 'battersFaced: 262', 'outs: 201', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 702', 'strikePercentage: .690', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 2', 'pickoffs: 0', 'totalBases: 90', 'groundOutsToAirouts: 0.71', 'winPercentage: .571', 'pitchesPerInning: 15.28', 'gamesFinished: 0', 'strikeoutWalkRatio: 8.11', 'strikeoutsPer9Inn: 9.81', 'walksPer9Inn: 1.21', 'hitsPer9Inn: 7.25', 'runsScoredPer9: 3.36', 'homeRunsPer9: 0.94', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 4', 'gamesStarted: 4', 'groundOuts: 12', 'airOuts: 24', 'runs: 20', 'doubles: 1', 'triples: 1', 'homeRuns: 4', 'strikeOuts: 13', 'baseOnBalls: 17', 'intentionalWalks: 0', 'hits: 19', 'hitByPitch: 0', 'avg: .279', 'atBats: 68', 'obp: .424', 'slg: .500', 'ops: .924', 'caughtStealing: 0', 'stolenBases: 6', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 0', 'numberOfPitches: 328', 'era: 9.92', 'inningsPitched: 16.1', 'wins: 0', 'losses: 4', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 18', 'whip: 2.20', 'battersFaced: 85', 'outs: 49', 'gamesPitched: 4', 'completeGames: 0', 'shutouts: 0', 'strikes: 185', 'strikePercentage: .560', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 34', 'groundOutsToAirouts: 0.50', 'winPercentage: .000', 'pitchesPerInning: 20.08', 'gamesFinished: 0', 'strikeoutWalkRatio: 0.76', 'strikeoutsPer9Inn: 7.16', 'walksPer9Inn: 9.37', 'hitsPer9Inn: 10.47', 'runsScoredPer9: 11.02', 'homeRunsPer9: 2.20', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 56', 'airOuts: 60', 'runs: 30', 'doubles: 6', 'triples: 0', 'homeRuns: 7', 'strikeOuts: 56', 'baseOnBalls: 25', 'intentionalWalks: 0', 'hits: 61', 'hitByPitch: 3', 'avg: .264', 'atBats: 231', 'obp: .342', 'slg: .381', 'ops: .723', 'caughtStealing: 2', 'stolenBases: 5', 'stolenBasePercentage: .714', 'groundIntoDoublePlay: 8', 'numberOfPitches: 1053', 'era: 4.03', 'inningsPitched: 60.1', 'wins: 5', 'losses: 6', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 27', 'whip: 1.43', 'battersFaced: 261', 'outs: 181', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 672', 'strikePercentage: .640', 'hitBatsmen: 3', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 88', 'groundOutsToAirouts: 0.93', 'winPercentage: .455', 'pitchesPerInning: 17.45', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.24', 'strikeoutsPer9Inn: 8.35', 'walksPer9Inn: 3.73', 'hitsPer9Inn: 9.10', 'runsScoredPer9: 4.48', 'homeRunsPer9: 1.04', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 1']
# ['gamesPlayed: 10', 'gamesStarted: 8', 'groundOuts: 55', 'airOuts: 56', 'runs: 18', 'doubles: 8', 'triples: 1', 'homeRuns: 4', 'strikeOuts: 36', 'baseOnBalls: 11', 'intentionalWalks: 0', 'hits: 46', 'hitByPitch: 1', 'avg: .238', 'atBats: 193', 'obp: .283', 'slg: .352', 'ops: .635', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 6', 'numberOfPitches: 751', 'era: 2.84', 'inningsPitched: 50.2', 'wins: 5', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 1', 'blownSaves: 0', 'earnedRuns: 16', 'whip: 1.13', 'battersFaced: 205', 'outs: 152', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 507', 'strikePercentage: .680', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 68', 'groundOutsToAirouts: 0.98', 'winPercentage: .714', 'pitchesPerInning: 14.82', 'gamesFinished: 0', 'strikeoutWalkRatio: 3.27', 'strikeoutsPer9Inn: 6.39', 'walksPer9Inn: 1.95', 'hitsPer9Inn: 8.17', 'runsScoredPer9: 3.20', 'homeRunsPer9: 0.71', 'inheritedRunners: 2', 'inheritedRunnersScored: 1', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 3', 'gamesStarted: 3', 'groundOuts: 11', 'airOuts: 19', 'runs: 9', 'doubles: 4', 'triples: 0', 'homeRuns: 2', 'strikeOuts: 8', 'baseOnBalls: 3', 'intentionalWalks: 0', 'hits: 15', 'hitByPitch: 0', 'avg: .283', 'atBats: 53', 'obp: .321', 'slg: .472', 'ops: .793', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 1', 'numberOfPitches: 213', 'era: 5.68', 'inningsPitched: 12.2', 'wins: 0', 'losses: 1', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 8', 'whip: 1.42', 'battersFaced: 56', 'outs: 38', 'gamesPitched: 3', 'completeGames: 0', 'shutouts: 0', 'strikes: 143', 'strikePercentage: .670', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 25', 'groundOutsToAirouts: 0.58', 'winPercentage: .000', 'pitchesPerInning: 16.82', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.67', 'strikeoutsPer9Inn: 5.68', 'walksPer9Inn: 2.13', 'hitsPer9Inn: 10.66', 'runsScoredPer9: 6.39', 'homeRunsPer9: 1.42', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 10', 'gamesStarted: 1', 'groundOuts: 24', 'airOuts: 15', 'runs: 18', 'doubles: 5', 'triples: 0', 'homeRuns: 2', 'strikeOuts: 9', 'baseOnBalls: 10', 'intentionalWalks: 0', 'hits: 25', 'hitByPitch: 1', 'avg: .347', 'atBats: 72', 'obp: .429', 'slg: .500', 'ops: .929', 'caughtStealing: 2', 'stolenBases: 0', 'stolenBasePercentage: .000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 340', 'era: 8.35', 'inningsPitched: 18.1', 'wins: 0', 'losses: 0', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 17', 'whip: 1.91', 'battersFaced: 84', 'outs: 55', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 207', 'strikePercentage: .610', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 2', 'pickoffs: 0', 'totalBases: 36', 'groundOutsToAirouts: 1.60', 'winPercentage: .---', 'pitchesPerInning: 18.55', 'gamesFinished: 7', 'strikeoutWalkRatio: 0.90', 'strikeoutsPer9Inn: 4.42', 'walksPer9Inn: 4.91', 'hitsPer9Inn: 12.27', 'runsScoredPer9: 8.84', 'homeRunsPer9: 0.98', 'inheritedRunners: 4', 'inheritedRunnersScored: 2', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 9', 'gamesStarted: 9', 'groundOuts: 45', 'airOuts: 60', 'runs: 19', 'doubles: 9', 'triples: 1', 'homeRuns: 5', 'strikeOuts: 43', 'baseOnBalls: 14', 'intentionalWalks: 0', 'hits: 39', 'hitByPitch: 1', 'avg: .210', 'atBats: 186', 'obp: .267', 'slg: .349', 'ops: .616', 'caughtStealing: 1', 'stolenBases: 3', 'stolenBasePercentage: .750', 'groundIntoDoublePlay: 1', 'numberOfPitches: 781', 'era: 3.24', 'inningsPitched: 50.0', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 18', 'whip: 1.06', 'battersFaced: 202', 'outs: 150', 'gamesPitched: 9', 'completeGames: 0', 'shutouts: 0', 'strikes: 511', 'strikePercentage: .650', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 65', 'groundOutsToAirouts: 0.75', 'winPercentage: .667', 'pitchesPerInning: 15.62', 'gamesFinished: 0', 'strikeoutWalkRatio: 3.07', 'strikeoutsPer9Inn: 7.74', 'walksPer9Inn: 2.52', 'hitsPer9Inn: 7.02', 'runsScoredPer9: 3.42', 'homeRunsPer9: 0.90', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 9', 'gamesStarted: 8', 'groundOuts: 39', 'airOuts: 39', 'runs: 23', 'doubles: 8', 'triples: 1', 'homeRuns: 5', 'strikeOuts: 36', 'baseOnBalls: 9', 'intentionalWalks: 0', 'hits: 37', 'hitByPitch: 2', 'avg: .248', 'atBats: 149', 'obp: .296', 'slg: .416', 'ops: .712', 'caughtStealing: 0', 'stolenBases: 0', 'stolenBasePercentage: .---', 'groundIntoDoublePlay: 6', 'numberOfPitches: 703', 'era: 3.96', 'inningsPitched: 38.2', 'wins: 2', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 17', 'whip: 1.19', 'battersFaced: 162', 'outs: 116', 'gamesPitched: 9', 'completeGames: 0', 'shutouts: 0', 'strikes: 449', 'strikePercentage: .640', 'hitBatsmen: 2', 'balks: 0', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 62', 'groundOutsToAirouts: 1.00', 'winPercentage: .500', 'pitchesPerInning: 18.18', 'gamesFinished: 0', 'strikeoutWalkRatio: 4.00', 'strikeoutsPer9Inn: 8.38', 'walksPer9Inn: 2.09', 'hitsPer9Inn: 8.61', 'runsScoredPer9: 5.35', 'homeRunsPer9: 1.16', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 52', 'airOuts: 64', 'runs: 30', 'doubles: 13', 'triples: 0', 'homeRuns: 7', 'strikeOuts: 53', 'baseOnBalls: 23', 'intentionalWalks: 0', 'hits: 54', 'hitByPitch: 3', 'avg: .244', 'atBats: 221', 'obp: .321', 'slg: .398', 'ops: .719', 'caughtStealing: 3', 'stolenBases: 7', 'stolenBasePercentage: .700', 'groundIntoDoublePlay: 4', 'numberOfPitches: 988', 'era: 3.45', 'inningsPitched: 57.1', 'wins: 2', 'losses: 3', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 22', 'whip: 1.34', 'battersFaced: 249', 'outs: 172', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 603', 'strikePercentage: .610', 'hitBatsmen: 3', 'balks: 0', 'wildPitches: 2', 'pickoffs: 0', 'totalBases: 88', 'groundOutsToAirouts: 0.81', 'winPercentage: .400', 'pitchesPerInning: 17.23', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.30', 'strikeoutsPer9Inn: 8.32', 'walksPer9Inn: 3.61', 'hitsPer9Inn: 8.48', 'runsScoredPer9: 4.71', 'homeRunsPer9: 1.10', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 8', 'gamesStarted: 8', 'groundOuts: 44', 'airOuts: 46', 'runs: 17', 'doubles: 6', 'triples: 0', 'homeRuns: 5', 'strikeOuts: 38', 'baseOnBalls: 8', 'intentionalWalks: 0', 'hits: 41', 'hitByPitch: 0', 'avg: .246', 'atBats: 167', 'obp: .277', 'slg: .371', 'ops: .648', 'caughtStealing: 0', 'stolenBases: 2', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 672', 'era: 3.45', 'inningsPitched: 44.1', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 17', 'whip: 1.11', 'battersFaced: 177', 'outs: 133', 'gamesPitched: 8', 'completeGames: 0', 'shutouts: 0', 'strikes: 461', 'strikePercentage: .690', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 4', 'pickoffs: 0', 'totalBases: 62', 'groundOutsToAirouts: 0.96', 'winPercentage: .667', 'pitchesPerInning: 15.16', 'gamesFinished: 0', 'strikeoutWalkRatio: 4.75', 'strikeoutsPer9Inn: 7.71', 'walksPer9Inn: 1.62', 'hitsPer9Inn: 8.32', 'runsScoredPer9: 3.45', 'homeRunsPer9: 1.02', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 10', 'gamesStarted: 10', 'groundOuts: 53', 'airOuts: 46', 'runs: 29', 'doubles: 14', 'triples: 0', 'homeRuns: 6', 'strikeOuts: 59', 'baseOnBalls: 23', 'intentionalWalks: 0', 'hits: 52', 'hitByPitch: 5', 'avg: .249', 'atBats: 209', 'obp: .336', 'slg: .402', 'ops: .738', 'caughtStealing: 4', 'stolenBases: 5', 'stolenBasePercentage: .556', 'groundIntoDoublePlay: 5', 'numberOfPitches: 927', 'era: 4.29', 'inningsPitched: 56.2', 'wins: 3', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 27', 'whip: 1.32', 'battersFaced: 238', 'outs: 170', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 600', 'strikePercentage: .650', 'hitBatsmen: 5', 'balks: 0', 'wildPitches: 0', 'pickoffs: 2', 'totalBases: 84', 'groundOutsToAirouts: 1.15', 'winPercentage: .600', 'pitchesPerInning: 16.36', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.57', 'strikeoutsPer9Inn: 9.37', 'walksPer9Inn: 3.65', 'hitsPer9Inn: 8.26', 'runsScoredPer9: 4.61', 'homeRunsPer9: 0.95', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 7', 'gamesStarted: 7', 'groundOuts: 34', 'airOuts: 39', 'runs: 14', 'doubles: 6', 'triples: 0', 'homeRuns: 4', 'strikeOuts: 46', 'baseOnBalls: 9', 'intentionalWalks: 0', 'hits: 29', 'hitByPitch: 4', 'avg: .196', 'atBats: 148', 'obp: .261', 'slg: .318', 'ops: .579', 'caughtStealing: 2', 'stolenBases: 7', 'stolenBasePercentage: .778', 'groundIntoDoublePlay: 0', 'numberOfPitches: 632', 'era: 3.12', 'inningsPitched: 40.1', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 14', 'whip: 0.94', 'battersFaced: 161', 'outs: 121', 'gamesPitched: 7', 'completeGames: 0', 'shutouts: 0', 'strikes: 414', 'strikePercentage: .660', 'hitBatsmen: 4', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 47', 'groundOutsToAirouts: 0.87', 'winPercentage: .667', 'pitchesPerInning: 15.67', 'gamesFinished: 0', 'strikeoutWalkRatio: 5.11', 'strikeoutsPer9Inn: 10.26', 'walksPer9Inn: 2.01', 'hitsPer9Inn: 6.47', 'runsScoredPer9: 3.12', 'homeRunsPer9: 0.89', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 5', 'gamesStarted: 5', 'groundOuts: 19', 'airOuts: 15', 'runs: 23', 'doubles: 6', 'triples: 1', 'homeRuns: 3', 'strikeOuts: 24', 'baseOnBalls: 11', 'intentionalWalks: 0', 'hits: 27', 'hitByPitch: 1', 'avg: .318', 'atBats: 85', 'obp: .402', 'slg: .518', 'ops: .920', 'caughtStealing: 0', 'stolenBases: 8', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 0', 'numberOfPitches: 412', 'era: 10.42', 'inningsPitched: 19.0', 'wins: 0', 'losses: 3', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 22', 'whip: 2.00', 'battersFaced: 97', 'outs: 57', 'gamesPitched: 5', 'completeGames: 0', 'shutouts: 0', 'strikes: 235', 'strikePercentage: .570', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 3', 'pickoffs: 0', 'totalBases: 44', 'groundOutsToAirouts: 1.27', 'winPercentage: .000', 'pitchesPerInning: 21.68', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.18', 'strikeoutsPer9Inn: 11.37', 'walksPer9Inn: 5.21', 'hitsPer9Inn: 12.79', 'runsScoredPer9: 10.89', 'homeRunsPer9: 1.42', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 0']
# ['gamesPlayed: 4', 'gamesStarted: 4', 'groundOuts: 27', 'airOuts: 27', 'runs: 6', 'doubles: 1', 'triples: 0', 'homeRuns: 0', 'strikeOuts: 13', 'baseOnBalls: 1', 'intentionalWalks: 0', 'hits: 21', 'hitByPitch: 3', 'avg: .250', 'atBats: 84', 'obp: .275', 'slg: .262', 'ops: .537', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 3', 'numberOfPitches: 322', 'era: 1.96', 'inningsPitched: 23.0', 'wins: 2', 'losses: 0', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 5', 'whip: 0.96', 'battersFaced: 92', 'outs: 69', 'gamesPitched: 4', 'completeGames: 0', 'shutouts: 0', 'strikes: 229', 'strikePercentage: .710', 'hitBatsmen: 3', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 22', 'groundOutsToAirouts: 1.00', 'winPercentage: 1.000', 'pitchesPerInning: 14.00', 'gamesFinished: 0', 'strikeoutWalkRatio: 13.00', 'strikeoutsPer9Inn: 5.09', 'walksPer9Inn: 0.39', 'hitsPer9Inn: 8.22', 'runsScoredPer9: 2.35', 'homeRunsPer9: 0.00', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 3']
# ['gamesPlayed: 6', 'gamesStarted: 6', 'groundOuts: 21', 'airOuts: 44', 'runs: 21', 'doubles: 7', 'triples: 0', 'homeRuns: 6', 'strikeOuts: 25', 'baseOnBalls: 12', 'intentionalWalks: 0', 'hits: 40', 'hitByPitch: 2', 'avg: .310', 'atBats: 129', 'obp: .375', 'slg: .504', 'ops: .879', 'caughtStealing: 2', 'stolenBases: 1', 'stolenBasePercentage: .333', 'groundIntoDoublePlay: 4', 'numberOfPitches: 509', 'era: 5.51', 'inningsPitched: 32.2', 'wins: 3', 'losses: 0', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 20', 'whip: 1.59', 'battersFaced: 144', 'outs: 98', 'gamesPitched: 6', 'completeGames: 0', 'shutouts: 0', 'strikes: 327', 'strikePercentage: .640', 'hitBatsmen: 2', 'balks: 0', 'wildPitches: 0', 'pickoffs: 0', 'totalBases: 65', 'groundOutsToAirouts: 0.48', 'winPercentage: 1.000', 'pitchesPerInning: 15.58', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.08', 'strikeoutsPer9Inn: 6.89', 'walksPer9Inn: 3.31', 'hitsPer9Inn: 11.02', 'runsScoredPer9: 5.79', 'homeRunsPer9: 1.65', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 6', 'gamesStarted: 6', 'groundOuts: 32', 'airOuts: 34', 'runs: 17', 'doubles: 7', 'triples: 0', 'homeRuns: 6', 'strikeOuts: 31', 'baseOnBalls: 7', 'intentionalWalks: 0', 'hits: 27', 'hitByPitch: 2', 'avg: .223', 'atBats: 121', 'obp: .275', 'slg: .430', 'ops: .705', 'caughtStealing: 1', 'stolenBases: 0', 'stolenBasePercentage: .000', 'groundIntoDoublePlay: 0', 'numberOfPitches: 483', 'era: 4.45', 'inningsPitched: 32.1', 'wins: 0', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 16', 'whip: 1.05', 'battersFaced: 133', 'outs: 97', 'gamesPitched: 6', 'completeGames: 0', 'shutouts: 0', 'strikes: 330', 'strikePercentage: .680', 'hitBatsmen: 2', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 52', 'groundOutsToAirouts: 0.94', 'winPercentage: .000', 'pitchesPerInning: 14.94', 'gamesFinished: 0', 'strikeoutWalkRatio: 4.43', 'strikeoutsPer9Inn: 8.63', 'walksPer9Inn: 1.95', 'hitsPer9Inn: 7.52', 'runsScoredPer9: 4.73', 'homeRunsPer9: 1.67', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 2', 'sacFlies: 1']
# ['gamesPlayed: 11', 'gamesStarted: 11', 'groundOuts: 60', 'airOuts: 43', 'runs: 36', 'doubles: 18', 'triples: 2', 'homeRuns: 6', 'strikeOuts: 42', 'baseOnBalls: 24', 'intentionalWalks: 2', 'hits: 65', 'hitByPitch: 1', 'avg: .313', 'atBats: 208', 'obp: .383', 'slg: .505', 'ops: .888', 'caughtStealing: 1', 'stolenBases: 6', 'stolenBasePercentage: .857', 'groundIntoDoublePlay: 3', 'numberOfPitches: 913', 'era: 5.92', 'inningsPitched: 48.2', 'wins: 1', 'losses: 6', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 32', 'whip: 1.83', 'battersFaced: 235', 'outs: 146', 'gamesPitched: 11', 'completeGames: 0', 'shutouts: 0', 'strikes: 572', 'strikePercentage: .630', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 105', 'groundOutsToAirouts: 1.40', 'winPercentage: .143', 'pitchesPerInning: 18.76', 'gamesFinished: 0', 'strikeoutWalkRatio: 1.75', 'strikeoutsPer9Inn: 7.77', 'walksPer9Inn: 4.44', 'hitsPer9Inn: 12.02', 'runsScoredPer9: 6.66', 'homeRunsPer9: 1.11', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 12', 'gamesStarted: 11', 'groundOuts: 60', 'airOuts: 61', 'runs: 35', 'doubles: 10', 'triples: 0', 'homeRuns: 13', 'strikeOuts: 73', 'baseOnBalls: 29', 'intentionalWalks: 1', 'hits: 54', 'hitByPitch: 0', 'avg: .219', 'atBats: 247', 'obp: .301', 'slg: .417', 'ops: .718', 'caughtStealing: 0', 'stolenBases: 1', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 1', 'numberOfPitches: 1088', 'era: 4.18', 'inningsPitched: 64.2', 'wins: 4', 'losses: 4', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 30', 'whip: 1.28', 'battersFaced: 277', 'outs: 194', 'gamesPitched: 12', 'completeGames: 0', 'shutouts: 0', 'strikes: 698', 'strikePercentage: .640', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 103', 'groundOutsToAirouts: 0.98', 'winPercentage: .500', 'pitchesPerInning: 16.82', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.52', 'strikeoutsPer9Inn: 10.16', 'walksPer9Inn: 4.04', 'hitsPer9Inn: 7.52', 'runsScoredPer9: 4.87', 'homeRunsPer9: 1.81', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 0']
# ['gamesPlayed: 10', 'gamesStarted: 10', 'groundOuts: 47', 'airOuts: 70', 'runs: 25', 'doubles: 6', 'triples: 0', 'homeRuns: 11', 'strikeOuts: 56', 'baseOnBalls: 16', 'intentionalWalks: 0', 'hits: 41', 'hitByPitch: 0', 'avg: .192', 'atBats: 213', 'obp: .248', 'slg: .376', 'ops: .624', 'caughtStealing: 0', 'stolenBases: 3', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 2', 'numberOfPitches: 882', 'era: 3.53', 'inningsPitched: 58.2', 'wins: 3', 'losses: 5', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 23', 'whip: 0.97', 'battersFaced: 230', 'outs: 176', 'gamesPitched: 10', 'completeGames: 0', 'shutouts: 0', 'strikes: 575', 'strikePercentage: .650', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 80', 'groundOutsToAirouts: 0.67', 'winPercentage: .375', 'pitchesPerInning: 15.03', 'gamesFinished: 0', 'strikeoutWalkRatio: 3.50', 'strikeoutsPer9Inn: 8.59', 'walksPer9Inn: 2.45', 'hitsPer9Inn: 6.29', 'runsScoredPer9: 3.84', 'homeRunsPer9: 1.69', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 1']
# ['gamesPlayed: 7', 'gamesStarted: 7', 'groundOuts: 64', 'airOuts: 15', 'runs: 20', 'doubles: 7', 'triples: 0', 'homeRuns: 5', 'strikeOuts: 34', 'baseOnBalls: 12', 'intentionalWalks: 0', 'hits: 43', 'hitByPitch: 3', 'avg: .279', 'atBats: 154', 'obp: .339', 'slg: .422', 'ops: .761', 'caughtStealing: 1', 'stolenBases: 2', 'stolenBasePercentage: .667', 'groundIntoDoublePlay: 11', 'numberOfPitches: 619', 'era: 4.32', 'inningsPitched: 41.2', 'wins: 3', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 20', 'whip: 1.32', 'battersFaced: 171', 'outs: 125', 'gamesPitched: 7', 'completeGames: 0', 'shutouts: 0', 'strikes: 388', 'strikePercentage: .630', 'hitBatsmen: 3', 'balks: 1', 'wildPitches: 1', 'pickoffs: 0', 'totalBases: 65', 'groundOutsToAirouts: 4.27', 'winPercentage: .600', 'pitchesPerInning: 14.86', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.83', 'strikeoutsPer9Inn: 7.34', 'walksPer9Inn: 2.59', 'hitsPer9Inn: 9.29', 'runsScoredPer9: 4.32', 'homeRunsPer9: 1.08', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 0', 'sacFlies: 2']
# ['gamesPlayed: 9', 'gamesStarted: 9', 'groundOuts: 57', 'airOuts: 53', 'runs: 20', 'doubles: 9', 'triples: 0', 'homeRuns: 4', 'strikeOuts: 34', 'baseOnBalls: 17', 'intentionalWalks: 0', 'hits: 48', 'hitByPitch: 0', 'avg: .253', 'atBats: 190', 'obp: .313', 'slg: .363', 'ops: .676', 'caughtStealing: 0', 'stolenBases: 3', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 5', 'numberOfPitches: 774', 'era: 3.60', 'inningsPitched: 50.0', 'wins: 4', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 20', 'whip: 1.30', 'battersFaced: 209', 'outs: 150', 'gamesPitched: 9', 'completeGames: 0', 'shutouts: 0', 'strikes: 498', 'strikePercentage: .640', 'hitBatsmen: 0', 'balks: 0', 'wildPitches: 4', 'pickoffs: 1', 'totalBases: 69', 'groundOutsToAirouts: 1.08', 'winPercentage: .667', 'pitchesPerInning: 15.48', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.00', 'strikeoutsPer9Inn: 6.12', 'walksPer9Inn: 3.06', 'hitsPer9Inn: 8.64', 'runsScoredPer9: 3.60', 'homeRunsPer9: 0.72', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 0', 'sacBunts: 1', 'sacFlies: 1']
# ['gamesPlayed: 2', 'gamesStarted: 2', 'groundOuts: 4', 'airOuts: 10', 'runs: 5', 'doubles: 2', 'triples: 0', 'homeRuns: 0', 'strikeOuts: 11', 'baseOnBalls: 5', 'intentionalWalks: 0', 'hits: 7', 'hitByPitch: 1', 'avg: .219', 'atBats: 32', 'obp: .342', 'slg: .281', 'ops: .623', 'caughtStealing: 0', 'stolenBases: 4', 'stolenBasePercentage: 1.000', 'groundIntoDoublePlay: 1', 'numberOfPitches: 164', 'era: 3.00', 'inningsPitched: 9.0', 'wins: 0', 'losses: 2', 'saves: 0', 'saveOpportunities: 0', 'holds: 0', 'blownSaves: 0', 'earnedRuns: 3', 'whip: 1.33', 'battersFaced: 39', 'outs: 27', 'gamesPitched: 2', 'completeGames: 0', 'shutouts: 0', 'strikes: 97', 'strikePercentage: .590', 'hitBatsmen: 1', 'balks: 0', 'wildPitches: 0', 'pickoffs: 1', 'totalBases: 9', 'groundOutsToAirouts: 0.40', 'winPercentage: .000', 'pitchesPerInning: 18.22', 'gamesFinished: 0', 'strikeoutWalkRatio: 2.20', 'strikeoutsPer9Inn: 11.00', 'walksPer9Inn: 5.00', 'hitsPer9Inn: 7.00', 'runsScoredPer9: 5.00', 'homeRunsPer9: 0.00', 'inheritedRunners: 0', 'inheritedRunnersScored: 0', 'catchersInterference: 1', 'sacBunts: 0', 'sacFlies: 0']
# <style type="text/css">
# #T_449d2 th {
#   font-size: 14px;
#   background-color: #f4f4f4;
# }
# #T_449d2 td {
#   padding: 6px;
#   border: 1px solid #ddd;
# }
# #T_449d2_row0_col0, #T_449d2_row0_col1, #T_449d2_row0_col2, #T_449d2_row0_col3, #T_449d2_row0_col4, #T_449d2_row0_col5, #T_449d2_row0_col6, #T_449d2_row0_col7, #T_449d2_row0_col13, #T_449d2_row1_col0, #T_449d2_row1_col1, #T_449d2_row1_col2, #T_449d2_row1_col3, #T_449d2_row1_col4, #T_449d2_row1_col5, #T_449d2_row1_col6, #T_449d2_row1_col7, #T_449d2_row1_col13, #T_449d2_row2_col0, #T_449d2_row2_col1, #T_449d2_row2_col2, #T_449d2_row2_col3, #T_449d2_row2_col4, #T_449d2_row2_col5, #T_449d2_row2_col6, #T_449d2_row2_col7, #T_449d2_row2_col13, #T_449d2_row3_col0, #T_449d2_row3_col1, #T_449d2_row3_col2, #T_449d2_row3_col3, #T_449d2_row3_col4, #T_449d2_row3_col5, #T_449d2_row3_col6, #T_449d2_row3_col7, #T_449d2_row3_col13, #T_449d2_row4_col0, #T_449d2_row4_col1, #T_449d2_row4_col2, #T_449d2_row4_col3, #T_449d2_row4_col4, #T_449d2_row4_col5, #T_449d2_row4_col6, #T_449d2_row4_col7, #T_449d2_row4_col13, #T_449d2_row5_col0, #T_449d2_row5_col1, #T_449d2_row5_col2, #T_449d2_row5_col3, #T_449d2_row5_col4, #T_449d2_row5_col5, #T_449d2_row5_col6, #T_449d2_row5_col7, #T_449d2_row5_col13, #T_449d2_row6_col0, #T_449d2_row6_col1, #T_449d2_row6_col2, #T_449d2_row6_col3, #T_449d2_row6_col4, #T_449d2_row6_col5, #T_449d2_row6_col6, #T_449d2_row6_col7, #T_449d2_row6_col13, #T_449d2_row7_col0, #T_449d2_row7_col1, #T_449d2_row7_col2, #T_449d2_row7_col3, #T_449d2_row7_col4, #T_449d2_row7_col5, #T_449d2_row7_col6, #T_449d2_row7_col7, #T_449d2_row7_col13, #T_449d2_row8_col0, #T_449d2_row8_col1, #T_449d2_row8_col2, #T_449d2_row8_col3, #T_449d2_row8_col4, #T_449d2_row8_col5, #T_449d2_row8_col6, #T_449d2_row8_col7, #T_449d2_row8_col13, #T_449d2_row9_col0, #T_449d2_row9_col1, #T_449d2_row9_col2, #T_449d2_row9_col3, #T_449d2_row9_col4, #T_449d2_row9_col5, #T_449d2_row9_col6, #T_449d2_row9_col7, #T_449d2_row9_col13, #T_449d2_row10_col0, #T_449d2_row10_col1, #T_449d2_row10_col2, #T_449d2_row10_col3, #T_449d2_row10_col4, #T_449d2_row10_col5, #T_449d2_row10_col6, #T_449d2_row10_col7, #T_449d2_row10_col13, #T_449d2_row11_col0, #T_449d2_row11_col1, #T_449d2_row11_col2, #T_449d2_row11_col3, #T_449d2_row11_col4, #T_449d2_row11_col5, #T_449d2_row11_col6, #T_449d2_row11_col7, #T_449d2_row11_col13, #T_449d2_row12_col0, #T_449d2_row12_col1, #T_449d2_row12_col2, #T_449d2_row12_col3, #T_449d2_row12_col4, #T_449d2_row12_col5, #T_449d2_row12_col6, #T_449d2_row12_col7, #T_449d2_row12_col13, #T_449d2_row13_col0, #T_449d2_row13_col1, #T_449d2_row13_col2, #T_449d2_row13_col3, #T_449d2_row13_col4, #T_449d2_row13_col5, #T_449d2_row13_col6, #T_449d2_row13_col7, #T_449d2_row13_col13, #T_449d2_row14_col0, #T_449d2_row14_col1, #T_449d2_row14_col2, #T_449d2_row14_col3, #T_449d2_row14_col4, #T_449d2_row14_col5, #T_449d2_row14_col6, #T_449d2_row14_col7, #T_449d2_row14_col13, #T_449d2_row15_col0, #T_449d2_row15_col1, #T_449d2_row15_col2, #T_449d2_row15_col3, #T_449d2_row15_col4, #T_449d2_row15_col5, #T_449d2_row15_col6, #T_449d2_row15_col7, #T_449d2_row15_col13, #T_449d2_row16_col0, #T_449d2_row16_col1, #T_449d2_row16_col2, #T_449d2_row16_col3, #T_449d2_row16_col4, #T_449d2_row16_col5, #T_449d2_row16_col6, #T_449d2_row16_col7, #T_449d2_row16_col13, #T_449d2_row17_col0, #T_449d2_row17_col1, #T_449d2_row17_col2, #T_449d2_row17_col3, #T_449d2_row17_col4, #T_449d2_row17_col5, #T_449d2_row17_col6, #T_449d2_row17_col7, #T_449d2_row17_col13, #T_449d2_row18_col0, #T_449d2_row18_col1, #T_449d2_row18_col2, #T_449d2_row18_col3, #T_449d2_row18_col4, #T_449d2_row18_col5, #T_449d2_row18_col6, #T_449d2_row18_col7, #T_449d2_row18_col13, #T_449d2_row19_col0, #T_449d2_row19_col1, #T_449d2_row19_col2, #T_449d2_row19_col3, #T_449d2_row19_col4, #T_449d2_row19_col5, #T_449d2_row19_col6, #T_449d2_row19_col7, #T_449d2_row19_col13, #T_449d2_row20_col0, #T_449d2_row20_col1, #T_449d2_row20_col2, #T_449d2_row20_col3, #T_449d2_row20_col4, #T_449d2_row20_col5, #T_449d2_row20_col6, #T_449d2_row20_col7, #T_449d2_row20_col13, #T_449d2_row21_col0, #T_449d2_row21_col1, #T_449d2_row21_col2, #T_449d2_row21_col3, #T_449d2_row21_c ...
#   text-align: center;
# }
# #T_449d2_row0_col8 {
#   background-color: #152772;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row0_col9 {
#   background-color: #5fc1c0;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row0_col10, #T_449d2_row0_col12, #T_449d2_row10_col9, #T_449d2_row11_col11, #T_449d2_row20_col8 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row0_col11, #T_449d2_row8_col12 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row1_col8 {
#   background-color: #24459c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row1_col9 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row1_col10, #T_449d2_row14_col12 {
#   background-color: #89d1ba;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row1_col11, #T_449d2_row2_col12 {
#   background-color: #2258a5;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row1_col12 {
#   background-color: #24489d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row2_col8 {
#   background-color: #2356a4;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row2_col9 {
#   background-color: #b4e2b6;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row2_col10 {
#   background-color: #a7dcb7;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row2_col11 {
#   background-color: #59bfc0;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row3_col8 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row3_col9 {
#   background-color: #eef8b3;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row3_col10 {
#   background-color: #f8fcc9;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row3_col11 {
#   background-color: #aedfb6;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row3_col12 {
#   background-color: #216bae;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row4_col8, #T_449d2_row7_col8 {
#   background-color: #243392;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row4_col9 {
#   background-color: #eaf7b1;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row4_col10, #T_449d2_row4_col11, #T_449d2_row9_col10, #T_449d2_row9_col11, #T_449d2_row13_col10, #T_449d2_row13_col11, #T_449d2_row16_col8, #T_449d2_row16_col9, #T_449d2_row16_col10, #T_449d2_row16_col11, #T_449d2_row18_col11, #T_449d2_row21_col12 {
#   background-color: #ffffd9;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row4_col12, #T_449d2_row12_col8, #T_449d2_row12_col10, #T_449d2_row18_col8 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row5_col8 {
#   background-color: #24449c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row5_col9 {
#   background-color: #2498c1;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row5_col10 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row5_col11 {
#   background-color: #2165ab;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row5_col12 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row6_col8 {
#   background-color: #253997;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row6_col9 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row6_col10, #T_449d2_row8_col10, #T_449d2_row15_col10, #T_449d2_row17_col10 {
#   background-color: #f0f9b8;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row6_col11, #T_449d2_row17_col11 {
#   background-color: #289cc1;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row6_col12 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row7_col9 {
#   background-color: #36abc3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_449d2_row7_col10, #T_449d2_row11_col10 {
#   background-color: #4ebbc2;
#   color: #000000;
#   text-align: center;
# }
# #T_449d2_row7
